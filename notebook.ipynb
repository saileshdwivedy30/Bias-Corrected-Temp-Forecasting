# %%
# ==============================
# 0) Environment & Installs
# ==============================

# %pip install -U cfgrib eccodes xarray herbie-data zarr numcodecs pandas pyarrow fsspec s3fs gcsfs adlfs
# %pip install -U "boto3==1.40.18"

# %pip uninstall -y eccodes eccodeslib eckitlib fckitlib cfgrib
# %pip install --force-reinstall \
  "xarray==2024.3.0" \
  "cfgrib==0.9.14.1" \
  "eccodes==2.39.2" "eccodeslib==2.39.2"

# Regridding deps (no xesmf wheels here)
# %pip install pyresample==1.27.1 pyproj shapely

# Cartopy (conda-forge wheels)
# %pip install --upgrade pip
# %pip install --extra-index-url=https://conda.anaconda.org/conda-forge cartopy

# CPU torch
# %pip install --index-url https://download.pytorch.org/whl/cpu "torch==2.4.1"

dbutils.library.restartPython()
# Out:
# DEPRECATION: Using the pkg_resources metadata backend is deprecated. pip 26.3 will enforce this behaviour change. A possible replacement is to use the default importlib.metadata backend, by unsetting the _PIP_USE_IMPORTLIB_METADATA environment variable. Discussion can be found at https://github.com/pypa/pip/issues/13317
# Requirement already satisfied: cfgrib in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (0.9.14.1)
# Collecting cfgrib
#   Downloading cfgrib-0.9.15.0-py3-none-any.whl.metadata (55 kB)
# Requirement already satisfied: eccodes in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (2.39.2)
# Collecting eccodes
#   Downloading eccodes-2.43.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: xarray in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (2024.3.0)
# Collecting xarray
#   Downloading xarray-2025.9.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: herbie-data in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (2025.7.0)
# Requirement already satisfied: zarr in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (3.1.2)
# Requirement already satisfied: numcodecs in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (0.16.2)
# Requirement already satisfied: pandas in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (2.3.2)
# Requirement already satisfied: pyarrow in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (21.0.0)
# Requirement already satisfied: fsspec in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (2025.9.0)
# Requirement already satisfied: s3fs in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (2025.9.0)
# Requirement already satisfied: gcsfs in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (2025.9.0)
# Requirement already satisfied: adlfs in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (2025.8.0)
# Requirement already satisfied: attrs>=19.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from cfgrib) (25.3.0)
# Requirement already satisfied: click in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from cfgrib) (8.2.1)
# Requirement already satisfied: numpy in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from cfgrib) (1.26.4)
# Requirement already satisfied: cffi in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from eccodes) (2.0.0)
# Requirement already satisfied: findlibs in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from eccodes) (0.1.2)
# Requirement already satisfied: eccodeslib in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from eccodes) (2.39.2)
# Requirement already satisfied: packaging>=24.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from xarray) (25.0)
# Requirement already satisfied: pyproj>=3.7.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from herbie-data) (3.7.2)
# Requirement already satisfied: requests>=2.23.3 in /databricks/python3/lib/python3.12/site-packages (from herbie-data) (2.32.2)
# Requirement already satisfied: toml>=0.10.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from herbie-data) (0.10.2)
# Requirement already satisfied: donfig>=0.8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from zarr) (0.8.1.post1)
# Requirement already satisfied: typing-extensions>=4.9 in /databricks/python3/lib/python3.12/site-packages (from zarr) (4.11.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from s3fs) (2.24.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from s3fs) (3.12.15)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (0.12.0)
# Requirement already satisfied: botocore<1.40.19,>=1.40.15 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.40.18)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /databricks/python3/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (6.6.4)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /databricks/python3/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.20.1)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /databricks/python3/lib/python3.12/site-packages (from botocore<1.40.19,>=1.40.15->aiobotocore<3.0.0,>=2.5.4->s3fs) (2.2.2)
# Requirement already satisfied: six>=1.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: idna>=2.0 in /databricks/python3/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.7)
# Requirement already satisfied: decorator>4.1.2 in /databricks/python3/lib/python3.12/site-packages (from gcsfs) (5.1.1)
# Requirement already satisfied: google-auth>=1.2 in /databricks/python3/lib/python3.12/site-packages (from gcsfs) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from gcsfs) (1.2.2)
# Requirement already satisfied: google-cloud-storage in /databricks/python3/lib/python3.12/site-packages (from gcsfs) (3.1.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in /databricks/python3/lib/python3.12/site-packages (from adlfs) (1.33.0)
# Requirement already satisfied: azure-datalake-store<0.1,>=0.0.53 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from adlfs) (0.0.53)
# Requirement already satisfied: azure-identity in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from adlfs) (1.25.0)
# Requirement already satisfied: azure-storage-blob>=12.17.0 in /databricks/python3/lib/python3.12/site-packages (from adlfs) (12.23.0)
# Requirement already satisfied: msal<2,>=1.16.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from azure-datalake-store<0.1,>=0.0.53->adlfs) (1.33.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /usr/lib/python3/dist-packages (from PyJWT[crypto]<3,>=1.0.0->msal<2,>=1.16.0->azure-datalake-store<0.1,>=0.0.53->adlfs) (2.7.0)
# Requirement already satisfied: cryptography<48,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from msal<2,>=1.16.0->azure-datalake-store<0.1,>=0.0.53->adlfs) (42.0.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.23.3->herbie-data) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.23.3->herbie-data) (2024.6.2)
# Requirement already satisfied: isodate>=0.6.1 in /databricks/python3/lib/python3.12/site-packages (from azure-storage-blob>=12.17.0->adlfs) (0.7.2)
# Requirement already satisfied: pycparser in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from cffi->eccodes) (2.23)
# Requirement already satisfied: pyyaml in /databricks/python3/lib/python3.12/site-packages (from donfig>=0.8->zarr) (6.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /databricks/python3/lib/python3.12/site-packages (from google-auth>=1.2->gcsfs) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /databricks/python3/lib/python3.12/site-packages (from google-auth>=1.2->gcsfs) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /databricks/python3/lib/python3.12/site-packages (from google-auth>=1.2->gcsfs) (4.9)
# Requirement already satisfied: pyasn1>=0.1.3 in /databricks/python3/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth>=1.2->gcsfs) (0.4.8)
# Requirement already satisfied: crc32c>=2.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from numcodecs[crc32c]>=0.14->zarr) (2.7.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from azure-identity->adlfs) (1.3.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from google-auth-oauthlib->gcsfs) (2.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs) (3.2.2)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /databricks/python3/lib/python3.12/site-packages (from google-cloud-storage->gcsfs) (2.20.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.4.2 in /databricks/python3/lib/python3.12/site-packages (from google-cloud-storage->gcsfs) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /databricks/python3/lib/python3.12/site-packages (from google-cloud-storage->gcsfs) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /databricks/python3/lib/python3.12/site-packages (from google-cloud-storage->gcsfs) (1.7.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /databricks/python3/lib/python3.12/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs) (1.69.2)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /databricks/python3/lib/python3.12/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs) (5.29.4)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /databricks/python3/lib/python3.12/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs) (1.26.1)
# Downloading cfgrib-0.9.15.0-py3-none-any.whl (48 kB)
# Downloading eccodes-2.43.0-py3-none-any.whl (44 kB)
# Downloading xarray-2025.9.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 7.8 MB/s  0:00:00
# Installing collected packages: eccodes, xarray, cfgrib
#   Attempting uninstall: eccodes
#     Found existing installation: eccodes 2.39.2
#     Uninstalling eccodes-2.39.2:
#       Successfully uninstalled eccodes-2.39.2
#   Attempting uninstall: xarray
#     Found existing installation: xarray 2024.3.0
#     Uninstalling xarray-2024.3.0:
#       Successfully uninstalled xarray-2024.3.0
#   Attempting uninstall: cfgrib
#     Found existing installation: cfgrib 0.9.14.1
#     Uninstalling cfgrib-0.9.14.1:
#       Successfully uninstalled cfgrib-0.9.14.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [cfgrib]
# Successfully installed cfgrib-0.9.15.0 eccodes-2.43.0 xarray-2025.9.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# DEPRECATION: Using the pkg_resources metadata backend is deprecated. pip 26.3 will enforce this behaviour change. A possible replacement is to use the default importlib.metadata backend, by unsetting the _PIP_USE_IMPORTLIB_METADATA environment variable. Discussion can be found at https://github.com/pypa/pip/issues/13317
# Requirement already satisfied: boto3==1.40.18 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (1.40.18)
# Requirement already satisfied: botocore<1.41.0,>=1.40.18 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from boto3==1.40.18) (1.40.18)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /databricks/python3/lib/python3.12/site-packages (from boto3==1.40.18) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from boto3==1.40.18) (0.13.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from botocore<1.41.0,>=1.40.18->boto3==1.40.18) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /databricks/python3/lib/python3.12/site-packages (from botocore<1.41.0,>=1.40.18->boto3==1.40.18) (2.2.2)
# Requirement already satisfied: six>=1.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.18->boto3==1.40.18) (1.17.0)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# DEPRECATION: Using the pkg_resources metadata backend is deprecated. pip 26.3 will enforce this behaviour change. A possible replacement is to use the default importlib.metadata backend, by unsetting the _PIP_USE_IMPORTLIB_METADATA environment variable. Discussion can be found at https://github.com/pypa/pip/issues/13317
# Found existing installation: eccodes 2.43.0
# Uninstalling eccodes-2.43.0:
#   Successfully uninstalled eccodes-2.43.0
# Found existing installation: eccodeslib 2.39.2
# Uninstalling eccodeslib-2.39.2:
#   Successfully uninstalled eccodeslib-2.39.2
# WARNING: Skipping eckitlib as it is not installed.
# WARNING: Skipping fckitlib as it is not installed.
# Found existing installation: cfgrib 0.9.15.0
# Uninstalling cfgrib-0.9.15.0:
#   Successfully uninstalled cfgrib-0.9.15.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# DEPRECATION: Using the pkg_resources metadata backend is deprecated. pip 26.3 will enforce this behaviour change. A possible replacement is to use the default importlib.metadata backend, by unsetting the _PIP_USE_IMPORTLIB_METADATA environment variable. Discussion can be found at https://github.com/pypa/pip/issues/13317
# Collecting xarray==2024.3.0
#   Downloading xarray-2024.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting cfgrib==0.9.14.1
#   Downloading cfgrib-0.9.14.1-py3-none-any.whl.metadata (55 kB)
# Collecting eccodes==2.39.2
#   Downloading eccodes-2.39.2-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting eccodeslib==2.39.2
#   Downloading eccodeslib-2.39.2-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.2 kB)
# Collecting numpy>=1.23 (from xarray==2024.3.0)
#   Downloading numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting packaging>=22 (from xarray==2024.3.0)
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pandas>=1.5 (from xarray==2024.3.0)
#   Downloading pandas-2.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
# Collecting attrs>=19.2 (from cfgrib==0.9.14.1)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting click (from cfgrib==0.9.14.1)
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting cffi (from eccodes==2.39.2)
#   Downloading cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.6 kB)
# Collecting findlibs (from eccodes==2.39.2)
#   Downloading findlibs-0.1.2-py3-none-any.whl.metadata (4.5 kB)
# Collecting python-dateutil>=2.8.2 (from pandas>=1.5->xarray==2024.3.0)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas>=1.5->xarray==2024.3.0)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.5->xarray==2024.3.0)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas>=1.5->xarray==2024.3.0)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting pycparser (from cffi->eccodes==2.39.2)
#   Downloading pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Downloading xarray-2024.3.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 41.7 MB/s  0:00:00
# Downloading cfgrib-0.9.14.1-py3-none-any.whl (48 kB)
# Downloading eccodes-2.39.2-cp312-cp312-manylinux_2_28_x86_64.whl (7.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 92.5 MB/s  0:00:00
# Downloading eccodeslib-2.39.2-cp312-cp312-manylinux_2_28_x86_64.whl (15.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 90.8 MB/s  0:00:00
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 141.6 MB/s  0:00:00
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
# Downloading pandas-2.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 160.8 MB/s  0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (219 kB)
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
# Downloading findlibs-0.1.2-py3-none-any.whl (10 kB)
# Downloading pycparser-2.23-py3-none-any.whl (118 kB)
# Installing collected packages: pytz, findlibs, eccodeslib, tzdata, six, pycparser, packaging, numpy, click, attrs, python-dateutil, cffi, pandas, eccodes, xarray, cfgrib
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: findlibs
#     Found existing installation: findlibs 0.1.2
#     Uninstalling findlibs-0.1.2:
#       Successfully uninstalled findlibs-0.1.2
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2025.2
#     Uninstalling tzdata-2025.2:
#       Successfully uninstalled tzdata-2025.2
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: pycparser
#     Found existing installation: pycparser 2.23
#     Uninstalling pycparser-2.23:
#       Successfully uninstalled pycparser-2.23
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: click
#     Found existing installation: click 8.2.1
#     Uninstalling click-8.2.1:
#       Successfully uninstalled click-8.2.1
#   Attempting uninstall: attrs
#     Found existing installation: attrs 25.3.0
#     Uninstalling attrs-25.3.0:
#       Successfully uninstalled attrs-25.3.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: cffi
#     Found existing installation: cffi 2.0.0
#     Uninstalling cffi-2.0.0:
#       Successfully uninstalled cffi-2.0.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.3.2
#     Uninstalling pandas-2.3.2:
#       Successfully uninstalled pandas-2.3.2
#   Attempting uninstall: xarray
#     Found existing installation: xarray 2025.9.0
#     Uninstalling xarray-2025.9.0:
#       Successfully uninstalled xarray-2025.9.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [cfgrib]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# herbie-data 2025.7.0 requires cfgrib>=0.9.15, but you have cfgrib 0.9.14.1 which is incompatible.
# herbie-data 2025.7.0 requires xarray>=2025.1.1, but you have xarray 2024.3.0 which is incompatible.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.3.3 which is incompatible.
# databricks-connect 16.4.2 requires numpy<2,>=1.15, but you have numpy 2.3.3 which is incompatible.
# mlflow-skinny 2.21.3 requires packaging<25, but you have packaging 25.0 which is incompatible.
# scipy 1.13.1 requires numpy<2.3,>=1.22.4, but you have numpy 2.3.3 which is incompatible.
# Successfully installed attrs-25.3.0 cffi-2.0.0 cfgrib-0.9.14.1 click-8.2.1 eccodes-2.39.2 eccodeslib-2.39.2 findlibs-0.1.2 numpy-2.3.3 packaging-25.0 pandas-2.3.2 pycparser-2.23 python-dateutil-2.9.0.post0 pytz-2025.2 six-1.17.0 tzdata-2025.2 xarray-2024.3.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# DEPRECATION: Using the pkg_resources metadata backend is deprecated. pip 26.3 will enforce this behaviour change. A possible replacement is to use the default importlib.metadata backend, by unsetting the _PIP_USE_IMPORTLIB_METADATA environment variable. Discussion can be found at https://github.com/pypa/pip/issues/13317
# Requirement already satisfied: pyresample==1.27.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (1.27.1)
# Requirement already satisfied: pyproj in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (3.7.2)
# Requirement already satisfied: shapely in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (2.1.1)
# Requirement already satisfied: setuptools>=3.2 in /usr/local/lib/python3.12/dist-packages (from pyresample==1.27.1) (75.8.0)
# Requirement already satisfied: configobj in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from pyresample==1.27.1) (5.0.9)
# Requirement already satisfied: pykdtree>=1.3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from pyresample==1.27.1) (1.4.3)
# Requirement already satisfied: pyyaml in /databricks/python3/lib/python3.12/site-packages (from pyresample==1.27.1) (6.0.1)
# Requirement already satisfied: numpy>=1.10.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from pyresample==1.27.1) (2.3.3)
# Requirement already satisfied: certifi in /databricks/python3/lib/python3.12/site-packages (from pyproj) (2024.6.2)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# DEPRECATION: Using the pkg_resources metadata backend is deprecated. pip 26.3 will enforce this behaviour change. A possible replacement is to use the default importlib.metadata backend, by unsetting the _PIP_USE_IMPORTLIB_METADATA environment variable. Discussion can be found at https://github.com/pypa/pip/issues/13317
# Requirement already satisfied: pip in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (25.2)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# DEPRECATION: Using the pkg_resources metadata backend is deprecated. pip 26.3 will enforce this behaviour change. A possible replacement is to use the default importlib.metadata backend, by unsetting the _PIP_USE_IMPORTLIB_METADATA environment variable. Discussion can be found at https://github.com/pypa/pip/issues/13317
# Looking in indexes: https://pypi.org/simple, https://conda.anaconda.org/conda-forge
# Requirement already satisfied: cartopy in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (0.25.0)
# Requirement already satisfied: numpy>=1.23 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from cartopy) (2.3.3)
# Requirement already satisfied: matplotlib>=3.6 in /databricks/python3/lib/python3.12/site-packages (from cartopy) (3.8.4)
# Requirement already satisfied: shapely>=2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from cartopy) (2.1.1)
# Requirement already satisfied: packaging>=21 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from cartopy) (25.0)
# Requirement already satisfied: pyshp>=2.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from cartopy) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /databricks/python3/lib/python3.12/site-packages (from matplotlib>=3.6->cartopy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.12/site-packages (from matplotlib>=3.6->cartopy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.12/site-packages (from matplotlib>=3.6->cartopy) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /databricks/python3/lib/python3.12/site-packages (from matplotlib>=3.6->cartopy) (1.4.4)
# Requirement already satisfied: pillow>=8 in /databricks/python3/lib/python3.12/site-packages (from matplotlib>=3.6->cartopy) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /databricks/python3/lib/python3.12/site-packages (from matplotlib>=3.6->cartopy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from matplotlib>=3.6->cartopy) (2.9.0.post0)
# Collecting numpy>=1.23 (from cartopy)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: certifi in /databricks/python3/lib/python3.12/site-packages (from pyproj>=3.3.1->cartopy) (2024.6.2)
# Requirement already satisfied: six>=1.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.17.0)
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 138.7 MB/s  0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.3
#     Uninstalling numpy-2.3.3:
#       Successfully uninstalled numpy-2.3.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# herbie-data 2025.7.0 requires cfgrib>=0.9.15, but you have cfgrib 0.9.14.1 which is incompatible.
# herbie-data 2025.7.0 requires xarray>=2025.1.1, but you have xarray 2024.3.0 which is incompatible.
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# DEPRECATION: Using the pkg_resources metadata backend is deprecated. pip 26.3 will enforce this behaviour change. A possible replacement is to use the default importlib.metadata backend, by unsetting the _PIP_USE_IMPORTLIB_METADATA environment variable. Discussion can be found at https://github.com/pypa/pip/issues/13317
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch==2.4.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (2.4.1+cpu)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.4.1) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /databricks/python3/lib/python3.12/site-packages (from torch==2.4.1) (4.11.0)
# Requirement already satisfied: sympy in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from torch==2.4.1) (1.13.3)
# Requirement already satisfied: networkx in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from torch==2.4.1) (3.3)
# Requirement already satisfied: jinja2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from torch==2.4.1) (3.1.4)
# Requirement already satisfied: fsspec in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from torch==2.4.1) (2025.9.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.4.1) (75.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from jinja2->torch==2.4.1) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ac9153e0-8fac-4cbf-b61e-f79e76bb393d/lib/python3.12/site-packages (from sympy->torch==2.4.1) (1.3.0)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# # ============================
# # RESET: Clear old artifacts & predictions
# # ============================

# ARTIFACT_DIR = "/Volumes/weather_ml/gold/artifacts"
# MODEL_PT     = f"{ARTIFACT_DIR}/bias_mlp3.pt"
# SCALER_JSON  = f"{ARTIFACT_DIR}/scaler_t2m.json"

# # Delete artifacts (scaler and model) from UC Volumes
# for p in [MODEL_PT, SCALER_JSON]:
#     try:
#         dbutils.fs.rm(p, recurse=True)
#         print("Deleted:", p)
#     except Exception as e:
#         print("Not found or could not delete:", p, "->", e)

# # Truncate predictions table
# spark.sql("TRUNCATE TABLE weather_ml.gold.predictions_grid_online")
# print("Truncated GOLD.predictions_grid_online")

# %%
# ==== CONFIG ====
CATALOG = "weather_ml"
BRONZE  = f"{CATALOG}.bronze"
SILVER  = f"{CATALOG}.silver"
GOLD    = f"{CATALOG}.gold"

# Replay window
ONLINE_START = "2024-10-02 00:00:00"
ONLINE_END   = "2024-10-07 23:00:00"

CONUS_LAT = (20.0, 55.0)
CONUS_LON = (-130.0, -60.0)
CLAMP_C   = (-60.0, 55.0)
MAX_LEAD  = 8
REGRID_ROI_KM = 50

# Online learning knobs
LR_UPDATE     = 3e-4
WEIGHT_DECAY  = 1e-3
CLIP_NORM     = 5.0
EPOCHS_UPDATE = 2
BATCH_UPDATE  = 4096
MIN_SUP_PAIRS = 50_000
WORSE_TOLERANCE_C = 0.05   # canary rollback threshold

# Scaler behavior
STD_FLOOR = 0.05
ZMAX      = 10.0

SEED = 42

# Storage
spark.sql(f"USE CATALOG {CATALOG}")
spark.sql("CREATE SCHEMA IF NOT EXISTS bronze")
spark.sql("CREATE SCHEMA IF NOT EXISTS silver")
spark.sql("CREATE SCHEMA IF NOT EXISTS gold")
spark.sql(f"CREATE VOLUME IF NOT EXISTS {BRONZE}.gfs_raw")
spark.sql(f"CREATE VOLUME IF NOT EXISTS {BRONZE}.urma_raw")
spark.sql(f"CREATE VOLUME IF NOT EXISTS {GOLD}.artifacts")

ARTIFACT_DIR = f"/Volumes/{GOLD.replace('.', '/')}/artifacts"
MODEL_PT     = f"{ARTIFACT_DIR}/bias_mlp3_online.pt"
SCALER_JSON  = f"{ARTIFACT_DIR}/scaler_online.json"

# Caches
GFS_CACHE  = "/tmp/herbie_cache/gfs"
URMA_CACHE = "/tmp/herbie_cache/urma"

# Reproducibilty + Spark UTC
import os, random, numpy as np, pandas as pd, torch, json
random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED)
spark.conf.set("spark.sql.session.timeZone", "UTC")

print("Config set.")
# Out:
# Config set.

# %%
# Bronze: raw grids
spark.sql(f"""
CREATE TABLE IF NOT EXISTS {BRONZE}.bronze_gfs_grid (
  run_time   TIMESTAMP,
  lead_hour  INT,
  valid_time TIMESTAMP,
  lat        DOUBLE,
  lon        DOUBLE,
  var        STRING,
  value_c    DOUBLE
) USING DELTA
""")

spark.sql(f"""
CREATE TABLE IF NOT EXISTS {BRONZE}.bronze_urma_grid (
  valid_time TIMESTAMP,
  lat        DOUBLE,
  lon        DOUBLE,
  var        STRING,
  value_c    DOUBLE
) USING DELTA
""")

# Bronze ingest log
spark.sql(f"""
CREATE TABLE IF NOT EXISTS {BRONZE}.bronze_ingest_log (
  ts         TIMESTAMP,
  stage      STRING,      -- 'gfs' or 'urma'
  run_time   TIMESTAMP,   -- set for gfs
  lead_hour  INT,         -- set for gfs
  valid_time TIMESTAMP,   -- set for urma
  status     STRING,      -- started/success/skip_exists/failed
  msg        STRING
) USING DELTA
""")


# Silver: URMA on GFS grid
spark.sql(f"""
CREATE TABLE IF NOT EXISTS {SILVER}.silver_urma_on_gfs (
  valid_time TIMESTAMP,
  lat        DOUBLE,
  lon        DOUBLE,
  y_obs_c    DOUBLE
) USING DELTA
""")

spark.sql(f"""
CREATE TABLE IF NOT EXISTS {SILVER}.silver_gfs_features (
  run_time TIMESTAMP,
  lead_hour INT,
  valid_time TIMESTAMP,
  lat DOUBLE, lon DOUBLE,
  gfs_t2m_c DOUBLE,
  lat_sin DOUBLE, lat_cos DOUBLE, lon_sin DOUBLE, lon_cos DOUBLE,
  hod_sin DOUBLE, hod_cos DOUBLE, doy_sin DOUBLE, doy_cos DOUBLE,
  cycle_idx TINYINT, lead_norm DOUBLE
) USING DELTA
""")

# Gold: predictions + logs + metrics
spark.sql(f"""
CREATE TABLE IF NOT EXISTS {GOLD}.predictions_grid_online (
  issue_time   TIMESTAMP,
  valid_time   TIMESTAMP,
  lat          DOUBLE,
  lon          DOUBLE,
  y_hat_c      DOUBLE,
  ingestion_ts TIMESTAMP
) USING DELTA
""")

spark.sql(f"""
CREATE TABLE IF NOT EXISTS {GOLD}.online_training_log (
  issue_time   TIMESTAMP,
  valid_time   TIMESTAMP,
  lat          DOUBLE,
  lon          DOUBLE,
  processed_ts TIMESTAMP
) USING DELTA
""")

spark.sql(f"""
CREATE TABLE IF NOT EXISTS {GOLD}.daily_metrics (
  day    DATE,
  metric STRING,
  value  DOUBLE
) USING DELTA
""")

print("Tables created.")
# Out:
# Tables created.

# %%
import xarray as xr
from herbie import Herbie
from pyresample import geometry, kd_tree
from pyspark.sql import functions as F, types as T

def wrap180_np(a): return ((a + 180.0) % 360.0) - 180.0

def as_naive_utc(x):
    t = pd.to_datetime(x, utc=True)
    # Scalar
    if isinstance(t, pd.Timestamp):
        return t.tz_localize(None)
    # Pandas array like
    if hasattr(t, "dt"):
        return t.dt.tz_localize(None)
    # Python datetime
    return pd.Timestamp(t).tz_localize(None)

def to_aware_utc(x):
    return pd.to_datetime(x, utc=True).to_pydatetime()



def hour_range(start, end):
    t = pd.to_datetime(start, utc=True).tz_localize(None)
    e = pd.to_datetime(end,   utc=True).tz_localize(None)
    out=[];
    while t <= e: out.append(t); t += pd.Timedelta(hours=1)
    return out

def cycle_hours(start, end): return [t for t in hour_range(start, end) if t.hour in (0,6,12,18)]

def get_t2m_c(ds: xr.Dataset):
    var=None
    for key in ["t2m","2t","TMP","t"]:
        if key in ds.data_vars: var = ds[key]; break
    if var is None:
        for v in ds.data_vars:
            meta = (str(ds[v].attrs)+v).lower()
            if ("2" in meta and "m" in meta) and ("temp" in meta or v.lower()=="t"):
                var = ds[v]; break
    if var is None: raise RuntimeError("2m temperature not found")
    vals = var
    if str(var.attrs.get("units","K")).lower().startswith("k"): vals = var - 273.15
    return vals

def open_t2m(rt_or_vt, model, fxx=None):

    # Normalize to tz naive UTC and pass as ISO string to Herbie
    ts = as_naive_utc(rt_or_vt)
    iso = ts.strftime("%Y-%m-%d %H:%M:%S")

    if model=="gfs":
        H = Herbie(iso, model="gfs", product="pgrb2.0p25", fxx=fxx, save_dir=GFS_CACHE)
    elif model=="urma":
        H = Herbie(iso, model="urma", product="anl", fxx=0, save_dir=URMA_CACHE)
    else:
        raise ValueError("model must be gfs or urma")
    os.makedirs(H.save_dir, exist_ok=True)
    H.download(verbose=False)
    ds = H.xarray(
        backend_kwargs={"indexpath": "", "filter_by_keys": {"shortName":"2t","typeOfLevel":"heightAboveGround","level":2}},
        remove_grib=False
    )
    return ds

def ds_to_rows(ds, run_time=None, lead_hour=None):
    t2m = get_t2m_c(ds).values
    lat_name = "latitude" if "latitude" in ds.coords else "lat"
    lon_name = "longitude" if "longitude" in ds.coords else "lon"
    lat = ds[lat_name].values; lon = ds[lon_name].values
    if lat.ndim==2 and lon.ndim==2: LAT, LON = lat, lon
    else: LON, LAT = np.meshgrid(lon, lat)
    df = pd.DataFrame({"lat": LAT.ravel().astype("float32"),
                       "lon": LON.ravel().astype("float32"),
                       "value_c": t2m.reshape(-1).astype("float32")})
    if run_time is not None:
        df["run_time"] = pd.to_datetime(run_time)
    if lead_hour is not None:
        df["lead_hour"] = int(lead_hour)
        df["valid_time"] = pd.to_datetime(run_time) + pd.to_timedelta(int(lead_hour), "h")
    for c in ("run_time","valid_time"):
        if c in df.columns: df[c] = pd.to_datetime(df[c], utc=True).dt.tz_localize(None)
    return df
# Out:
#  ╭─▌▌Herbie─────────────────────────────────────────────╮
#  │ INFO: Created a default config file.                 │
#  │ You may view/edit Herbie's configuration here:       │
#  │ /home/spark-d578e990-ab81-4bfe-a426-f9/.config/herbie/config.toml   │
#  ╰──────────────────────────────────────────────────────╯

# %%
# Bronze appenders (with CONUS clip for GFS to save space)

def append_gfs_delta(df, parts=64, conus_only=True):
    if len(df) == 0:
        return
    # Optional CONUS clip
    if conus_only:
        lon = wrap180_np(df["lon"].to_numpy())
        m = (df["lat"].between(*CONUS_LAT)) & (pd.Series(lon).between(*CONUS_LON))
        df = df.loc[m].copy()
        if len(df) == 0:
            return
        df["lon"] = lon[m]

    # Normalize timestamps to strings to Timestamp to avoid tz issues
    tmp = df.copy()
    tmp["run_time"]   = pd.to_datetime(tmp["run_time"],  utc=True).dt.tz_localize(None)
    tmp["valid_time"] = pd.to_datetime(tmp["valid_time"], utc=True).dt.tz_localize(None)

    up = (spark.createDataFrame(tmp[["run_time","lead_hour","valid_time","lat","lon","value_c"]])
            .select(
                F.to_timestamp("run_time").alias("run_time"),
                F.col("lead_hour").cast("int").alias("lead_hour"),
                F.to_timestamp("valid_time").alias("valid_time"),
                F.col("lat").cast("double").alias("lat"),
                F.col("lon").cast("double").alias("lon"),
                F.col("value_c").cast("double").alias("value_c"),
                F.lit("t2m").alias("var"))
         )

    up.createOrReplaceTempView("_up_gfs")

    spark.sql(f"""
    MERGE INTO {BRONZE}.bronze_gfs_grid AS t
    USING _up_gfs AS s
    ON  t.run_time  = s.run_time
    AND t.lead_hour = s.lead_hour
    AND t.lat       = s.lat
    AND t.lon       = s.lon
    AND t.var       = s.var
    WHEN NOT MATCHED THEN INSERT (
        run_time,  lead_hour, valid_time, lat,  lon,  var,  value_c
    ) VALUES (
        s.run_time, s.lead_hour, s.valid_time, s.lat, s.lon, s.var, s.value_c
    )
    """)

def append_urma_delta(df, parts=64):
    if len(df) == 0:
        return
    tmp = df.copy()
    tmp["valid_time"] = pd.to_datetime(tmp["valid_time"], utc=True).dt.tz_localize(None)

    up = (spark.createDataFrame(tmp[["valid_time","lat","lon","value_c"]])
            .select(
                F.to_timestamp("valid_time").alias("valid_time"),
                F.col("lat").cast("double"),
                F.col("lon").cast("double"),
                F.col("value_c").cast("double"),
                F.lit("t2m").alias("var"))
         )

    up.createOrReplaceTempView("_up_urma")

    spark.sql(f"""
    MERGE INTO {BRONZE}.bronze_urma_grid AS t
    USING _up_urma AS s
    ON  t.valid_time = s.valid_time
    AND t.lat        = s.lat
    AND t.lon        = s.lon
    AND t.var        = s.var
    WHEN NOT MATCHED THEN INSERT (
        valid_time, lat, lon, var, value_c
    ) VALUES (
        s.valid_time, s.lat, s.lon, s.var, s.value_c
    )
    """)

def missing_gfs_leads_for_cycle(rt0):
    want = spark.createDataFrame([(int(h),) for h in range(0, MAX_LEAD+1)], "lead_hour INT")
    have = (spark.table(f"{BRONZE}.bronze_gfs_grid")
            .where(F.col("run_time")==F.to_timestamp(F.lit(as_naive_utc(rt0).strftime("%Y-%m-%d %H:%M:%S"))))
            .select("lead_hour").distinct())
    todo = want.join(have, "lead_hour", "left_anti").orderBy("lead_hour")
    return [r["lead_hour"] for r in todo.collect()]

def missing_urma_hours_for_cycle(rt0):
    hours = [as_naive_utc(rt0) + pd.Timedelta(hours=h) for h in range(3, MAX_LEAD+1)]
    sdf   = spark.createDataFrame([(pd.to_datetime(v).strftime("%Y-%m-%d %H:%M:%S"),) for v in hours], "vt_str STRING") \
                 .select(F.to_timestamp("vt_str").alias("valid_time"))
    have  = spark.table(f"{BRONZE}.bronze_urma_grid").select("valid_time").distinct()
    todo  = sdf.join(have, ["valid_time"], "left_anti").orderBy("valid_time")
    # return tz naive UTC python datetimes for Herbie/open_t2m
    return [pd.Timestamp(r["valid_time"]).to_pydatetime().replace(tzinfo=None) for r in todo.collect()]

# Historical replay ingestion for a run_time (GFS +0..8, URMA for +3..8)
def _log_ingest(stage, run_time=None, lead_hour=None, valid_time=None, status="started", msg=None):
    rows = [(
        to_aware_utc(pd.Timestamp.utcnow()),          # ts (aware)
        stage,
        to_aware_utc(as_naive_utc(run_time)) if run_time is not None else None,
        int(lead_hour) if lead_hour is not None else None,
        to_aware_utc(as_naive_utc(valid_time)) if valid_time is not None else None,
        status,
        str(msg) if msg else None
    )]
    (spark.createDataFrame(
        rows,
        "ts TIMESTAMP, stage STRING, run_time TIMESTAMP, lead_hour INT, valid_time TIMESTAMP, status STRING, msg STRING"
     ).write.mode("append").saveAsTable(f"{BRONZE}.bronze_ingest_log"))

def ingest_cycle(rt):
    rt0 = as_naive_utc(rt)

    # GFS 0..MAX_LEAD (resume safe)
    todo_leads = missing_gfs_leads_for_cycle(rt0)
    for h in todo_leads:
        _log_ingest("gfs", run_time=rt0, lead_hour=h, status="started")
        try:
            ds = open_t2m(rt0, "gfs", fxx=h)
            append_gfs_delta(ds_to_rows(ds, run_time=rt0, lead_hour=h), conus_only=True)
            _log_ingest("gfs", run_time=rt0, lead_hour=h, status="success")
        except Exception as e:
            _log_ingest("gfs", run_time=rt0, lead_hour=h, status="failed", msg=e)

    if not todo_leads:
        _log_ingest("gfs", run_time=rt0, status="skip_exists", msg="all leads present")

    # URMA for +3..MAX_LEAD (resume safe)
    todo_vts = missing_urma_hours_for_cycle(rt0)
    for vt in todo_vts:
        _log_ingest("urma", valid_time=vt, status="started")
        try:
            ds = open_t2m(vt, "urma")
            df = ds_to_rows(ds); df["valid_time"] = as_naive_utc(vt)
            append_urma_delta(df)
            _log_ingest("urma", valid_time=vt, status="success")
        except Exception as e:
            _log_ingest("urma", valid_time=vt, status="failed", msg=e)

    if not todo_vts:
        _log_ingest("urma", run_time=rt0, status="skip_exists", msg="all vt present for +3..+8")

# Silver: regrid URMA to first cycle's GFS CONUS grid once, then append hours
def build_conus_target_grid(rt):
    ds0 = open_t2m(rt, "gfs", fxx=0)
    lat_name = "latitude" if "latitude" in ds0.coords else "lat"
    lon_name = "longitude" if "longitude" in ds0.coords else "lon"
    g_lat = ds0[lat_name].values; g_lon = ds0[lon_name].values
    if g_lat.ndim==1 and g_lon.ndim==1: LONg, LATg = np.meshgrid(g_lon, g_lat)
    else: LATg, LONg = g_lat, g_lon
    LONg = wrap180_np(LONg)
    row_mask = (LATg[:,0] >= CONUS_LAT[0]) & (LATg[:,0] <= CONUS_LAT[1])
    col_mask = (LONg[0,:] >= CONUS_LON[0]) & (LONg[0,:] <= CONUS_LON[1])
    LATg_c = LATg[row_mask][:, col_mask]
    LONg_c = LONg[row_mask][:, col_mask]
    return LATg_c, LONg_c

LATg_c, LONg_c = build_conus_target_grid(ONLINE_START)
swath_tgt = geometry.SwathDefinition(lons=LONg_c, lats=LATg_c)

def regrid_urma_to_gfs(vt):
    vt0 = as_naive_utc(vt)  # one normalization step

    dsu = open_t2m(vt0, "urma")
    var = get_t2m_c(dsu).values
    src_lat = dsu["latitude"].values if "latitude" in dsu.coords else dsu["lat"].values
    src_lon = dsu["longitude"].values if "longitude" in dsu.coords else dsu["lon"].values
    src_lon = wrap180_np(src_lon)

    swath_src = geometry.SwathDefinition(lons=src_lon, lats=src_lat)
    t2m_on_gfs = kd_tree.resample_nearest(
        swath_src, var, swath_tgt,
        radius_of_influence=REGRID_ROI_KM*1000, fill_value=np.nan
    )

    out = pd.DataFrame({
        "valid_time_str": pd.to_datetime(vt0).strftime("%Y-%m-%d %H:%M:%S"),
        "lat": LATg_c.ravel().astype("float64"),
        "lon": LONg_c.ravel().astype("float64"),
        "y_obs_c": t2m_on_gfs.reshape(-1).astype("float64"),
    })
    out = out[np.isfinite(out["y_obs_c"].values)]
    if out.empty:
        return

    s_new = (spark.createDataFrame(out)
             .select(
                 F.to_timestamp("valid_time_str").alias("valid_time"),
                 F.col("lat").cast("double"),
                 F.col("lon").cast("double"),
                 F.col("y_obs_c").cast("double")
             ))

    vts = out["valid_time_str"].iloc[0]
    existing = (spark.table(f"{SILVER}.silver_urma_on_gfs")
                    .where(F.col("valid_time")==F.to_timestamp(F.lit(vts)))
                    .select("lat","lon"))
    s_write = s_new.join(existing, ["lat","lon"], "left_anti")

    if s_write.limit(1).count() > 0:
        s_write.write.mode("append").saveAsTable(f"{SILVER}.silver_urma_on_gfs")

# Silver features (from Bronze GFS) for current cycle
def build_silver_features_for_cycle(rt):
    spark.sql(f"""
    INSERT OVERWRITE TABLE {SILVER}.silver_gfs_features
    SELECT
      run_time,
      lead_hour,
      timestampadd(HOUR, lead_hour, run_time) AS valid_time,
      CAST(lat AS DOUBLE) AS lat,
      CAST(pmod(lon + 180.0, 360.0) - 180.0 AS DOUBLE) AS lon,
      GREATEST(LEAST(CAST(value_c AS DOUBLE), {CLAMP_C[1]}), {CLAMP_C[0]}) AS gfs_t2m_c,
      SIN(RADIANS(lat)) AS lat_sin, COS(RADIANS(lat)) AS lat_cos,
      SIN(RADIANS(pmod(lon + 180.0, 360.0) - 180.0)) AS lon_sin,
      COS(RADIANS(pmod(lon + 180.0, 360.0) - 180.0)) AS lon_cos,
      SIN(2*PI()*HOUR(timestampadd(HOUR, lead_hour, run_time))/24.0)  AS hod_sin,
      COS(2*PI()*HOUR(timestampadd(HOUR, lead_hour, run_time))/24.0)  AS hod_cos,
      SIN(2*PI()*DAYOFYEAR(timestampadd(HOUR, lead_hour, run_time))/366.0) AS doy_sin,
      COS(2*PI()*DAYOFYEAR(timestampadd(HOUR, lead_hour, run_time))/366.0) AS doy_cos,
      CASE HOUR(run_time) WHEN 0 THEN 0 WHEN 6 THEN 1 WHEN 12 THEN 2 ELSE 3 END AS cycle_idx,
      lead_hour / 120.0 AS lead_norm
    FROM {BRONZE}.bronze_gfs_grid
    WHERE run_time = TIMESTAMP '{as_naive_utc(rt).strftime('%Y-%m-%d %H:%M:%S')}'
      AND var='t2m'
      AND lead_hour BETWEEN 0 AND {MAX_LEAD}
      AND lat BETWEEN {CONUS_LAT[0]} AND {CONUS_LAT[1]}
      AND (pmod(lon + 180.0, 360.0) - 180.0) BETWEEN {CONUS_LON[0]} AND {CONUS_LON[1]}
    """)
# Out:
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# 👨🏻‍🏭 Created directory: [/tmp/herbie_cache/gfs/gfs/20241001]

# %%
def agg_for_leads(df, leads, prefix):
    exprs=[]
    for i,h in enumerate(leads):
        exprs += [
            F.max(F.when(F.col("lead_hour")==h, F.col("gfs_t2m_c"))).alias(f"{prefix}{i}"),
            F.max(F.when(F.col("lead_hour")==h, F.col("hod_sin"))).alias(f"{prefix}t{i}_hod_sin"),
            F.max(F.when(F.col("lead_hour")==h, F.col("hod_cos"))).alias(f"{prefix}t{i}_hod_cos"),
            F.max(F.when(F.col("lead_hour")==h, F.col("doy_sin"))).alias(f"{prefix}t{i}_doy_sin"),
            F.max(F.when(F.col("lead_hour")==h, F.col("doy_cos"))).alias(f"{prefix}t{i}_doy_cos"),
        ]
    return df.groupBy("run_time","lat","lon").agg(*exprs)

def build_block_wide(rt_ts, block_id):
    sf = (spark.table(f"{SILVER}.silver_gfs_features")
          .where(F.col("run_time")==F.to_timestamp(F.lit(rt_ts)))
          .select("run_time","valid_time","lat","lon","lead_hour",
                  "gfs_t2m_c","hod_sin","hod_cos","doy_sin","doy_cos"))

    if block_id==0:
        x_leads, g_leads, base_lead = [0,1,2], [3,4,5], 3
    else:
        x_leads, g_leads, base_lead = [3,4,5], [6,7,8], 6

    xw = agg_for_leads(sf, x_leads, "x")
    gw = agg_for_leads(sf, g_leads, "g")

    w = (xw.join(gw, ["run_time","lat","lon"], "inner")
           .withColumn("block_id", F.lit(block_id).cast("int"))
           .withColumn("lon_wrapped", (F.pmod(F.col("lon")+180.0, 360.0)-180.0))
           .withColumn("lat_sin", F.sin(F.radians(F.col("lat"))))
           .withColumn("lat_cos", F.cos(F.radians(F.col("lat"))))
           .withColumn("lon_sin", F.sin(F.radians(F.col("lon_wrapped"))))
           .withColumn("lon_cos", F.cos(F.radians(F.col("lon_wrapped"))))
           .withColumn("cycle_idx",
               F.when(F.hour("run_time")==0,0).when(F.hour("run_time")==6,1)
                .when(F.hour("run_time")==12,2).otherwise(3).cast("byte"))
           .withColumnRenamed("gt0_hod_sin","t0_hod_sin").withColumnRenamed("gt0_hod_cos","t0_hod_cos")
           .withColumnRenamed("gt0_doy_sin","t0_doy_sin").withColumnRenamed("gt0_doy_cos","t0_doy_cos")
           .withColumnRenamed("gt1_hod_sin","t1_hod_sin").withColumnRenamed("gt1_hod_cos","t1_hod_cos")
           .withColumnRenamed("gt1_doy_sin","t1_doy_sin").withColumnRenamed("gt1_doy_cos","t1_doy_cos")
           .withColumnRenamed("gt2_hod_sin","t2_hod_sin").withColumnRenamed("gt2_hod_cos","t2_hod_cos")
           .withColumnRenamed("gt2_doy_sin","t2_doy_sin").withColumnRenamed("gt2_doy_cos","t2_doy_cos")
         )

    sel = [
        "run_time","lat",F.col("lon_wrapped").alias("lon"),"block_id",
        "x0","x1","x2","g0","g1","g2",
        "lat_sin","lat_cos","lon_sin","lon_cos",
        "t0_hod_sin","t0_hod_cos","t0_doy_sin","t0_doy_cos",
        "t1_hod_sin","t1_hod_cos","t1_doy_sin","t1_doy_cos",
        "t2_hod_sin","t2_hod_cos","t2_doy_sin","t2_doy_cos"
    ]
    return w.select(*sel), base_lead

# %%
import torch.nn as nn, torch.nn.functional as Ftorch
from dataclasses import dataclass

# FEATURES order
FEATURES = [
    "x0","x1","x2","g0","g1","g2",
    "lat_sin","lat_cos","lon_sin","lon_cos",
    "t0_hod_sin","t0_hod_cos","t0_doy_sin","t0_doy_cos",
    "t1_hod_sin","t1_hod_cos","t1_doy_sin","t1_doy_cos",
    "t2_hod_sin","t2_hod_cos","t2_doy_sin","t2_doy_cos",
    "block_flag"
]
D_IN = len(FEATURES)

class MLP3(nn.Module):
    def __init__(self, d_in=D_IN, h=64, p=0.10):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(d_in, h), nn.ReLU(), nn.Dropout(p),
            nn.Linear(h, h),    nn.ReLU(), nn.Dropout(p),
            nn.Linear(h, 3)
        )
    def forward(self, x): return self.net(x)

# Running scaler persisted to JSON
@dataclass
class RunningScaler:
    n:   int
    mu:  np.ndarray
    m2:  np.ndarray

    @staticmethod
    def init(d):
        return RunningScaler(0, np.zeros(d, np.float32), np.zeros(d, np.float32))

    def update(self, X):
        # X: [N, D]
        X = np.asarray(X, np.float32)
        for row in X:
            self.n += 1
            delta = row - self.mu
            self.mu += delta / self.n
            delta2 = row - self.mu
            self.m2 += delta * delta2

    def std(self):
        if self.n < 2:
            return np.ones_like(self.mu, np.float32)
        var = self.m2 / (self.n - 1)
        std = np.sqrt(np.maximum(var, STD_FLOOR**2)).astype(np.float32)
        return std

    def z(self, X):
        X = np.asarray(X, np.float32)
        sd = self.std()
        Z = (X - self.mu) / sd
        Z[~np.isfinite(Z)] = 0.0
        np.clip(Z, -ZMAX, ZMAX, out=Z)
        return Z

def load_or_init_scaler(d=D_IN):
    if os.path.exists(SCALER_JSON):
        s = json.load(open(SCALER_JSON,"r"))
        rs = RunningScaler(s["n"], np.array(s["mu"], np.float32), np.array(s["m2"], np.float32))
    else:
        rs = RunningScaler.init(d)
    return rs

def save_scaler(rs: RunningScaler):
    os.makedirs(ARTIFACT_DIR, exist_ok=True)
    json.dump({"n": rs.n, "mu": rs.mu.tolist(), "m2": rs.m2.tolist()}, open(SCALER_JSON,"w"))

def load_or_init_model():
    m = MLP3(D_IN)
    if os.path.exists(MODEL_PT):
        state = torch.load(MODEL_PT, map_location="cpu")
        m.load_state_dict(state)
    m.eval()
    return m

def save_model(m: nn.Module):
    os.makedirs(ARTIFACT_DIR, exist_ok=True)
    torch.save(m.state_dict(), MODEL_PT)

def mae_np(a,b):
    a,b = np.asarray(a), np.asarray(b)
    return float(np.nanmean(np.abs(a-b))) if a.size else float("nan")

# %%
from pyspark.sql import types as T

pred_schema = T.StructType([
    T.StructField("issue_time", T.TimestampType()),
    T.StructField("valid_time", T.TimestampType()),
    T.StructField("lat", T.DoubleType()),
    T.StructField("lon", T.DoubleType()),
    T.StructField("y_hat_c", T.DoubleType()),
    T.StructField("ingestion_ts", T.TimestampType())
])

def predict_block(rt_ts, block_id, model, scaler: RunningScaler):
    W, base_lead = build_block_wide(rt_ts, block_id)
    pdf = W.toPandas()
    if pdf.empty: return 0
    pdf["block_flag"] = pdf["block_id"].astype(np.float32)
    X = pdf[FEATURES].to_numpy(np.float32)
    Xz = scaler.z(X) # predict with current scaler snapshot
    G = pdf[["g0","g1","g2"]].to_numpy(np.float32)

    with torch.no_grad():
        rhat = model(torch.from_numpy(Xz)).cpu().numpy().astype(np.float32)
    Yhat = G + rhat

    # idempotency (avoid duplicates)
    ex = (spark.table(f"{GOLD}.predictions_grid_online")
            .where(F.col("issue_time")==F.to_timestamp(F.lit(rt_ts)))
            .select("valid_time","lat","lon").distinct().toPandas())

    existing = set() if ex.empty else set((#pd.Timestamp(v),
                                           as_naive_utc(v),
                                           round(float(a),6), round(float(o),6)) for v,a,o in ex.itertuples(index=False))


    rt = as_naive_utc(rt_ts) # keep internal tz naive
    now_ts = as_naive_utc(pd.Timestamp.utcnow())  # keep internal tz naive
    vtimes = [rt + pd.Timedelta(hours=base_lead + k) for k in range(3)]

    it_aw  = to_aware_utc(rt) # tz aware UTC for Spark
    now_aw = to_aware_utc(now_ts) # tz aware UTC for Spark

    rows=[]
    for i,(lat,lon) in enumerate(pdf[["lat","lon"]].values):
        lat_i = round(float(lat),6); lon_i = round(float(lon),6)
        for k in range(3):
            vt_k = vtimes[k]  # tz naive internally
            key = (vt_k, lat_i, lon_i)
            if key in existing:
                continue
            rows.append((it_aw, to_aware_utc(vt_k), float(lat_i), float(lon_i), float(Yhat[i,k]), now_aw))

    if rows:
        (spark.createDataFrame(rows, pred_schema)
            .write.mode("append").saveAsTable(f"{GOLD}.predictions_grid_online"))
    return len(rows)


def update_block(rt_ts, block_id, model, scaler: RunningScaler):
    # collect supervised pairs for this block and join preds+URMA for the block's valid hours
    rt = as_naive_utc(rt_ts)
    base_lead = 3 if block_id == 0 else 6
    vts = [rt + pd.Timedelta(hours=h) for h in (base_lead, base_lead+1, base_lead+2)]

    # preds subset (alias as p)
    p = (spark.table(f"{GOLD}.predictions_grid_online").alias("p")
         .where((F.col("p.issue_time") == F.to_timestamp(F.lit(rt_ts))) &
                (F.col("p.valid_time").between(
                    vts[0].strftime("%Y-%m-%d %H:%M:%S"),
                    vts[-1].strftime("%Y-%m-%d %H:%M:%S")
                )))
         .select("p.issue_time","p.valid_time","p.lat","p.lon"))

    if p.limit(1).count() == 0:
        return "no_preds"

    # URMA on GFS grid (alias as u)
    u = (spark.table(f"{SILVER}.silver_urma_on_gfs")
         .select(F.col("valid_time").alias("vt"), "lat", "lon", "y_obs_c")
         .alias("u"))

    # already processed idempotency log (alias as pr)
    pr = (spark.table(f"{GOLD}.online_training_log")
          .where(F.col("issue_time") == F.to_timestamp(F.lit(rt_ts)))
          .select("valid_time","lat","lon")
          .distinct()
          .alias("pr"))

    # join preds with truth, then drop anything already processed
    j1 = (p.join(
            u,
            (F.col("p.valid_time") == F.col("u.vt")) &
            (F.col("p.lat")        == F.col("u.lat")) &
            (F.col("p.lon")        == F.col("u.lon")),
            "inner"
          )
          # project a single, unambiguous set of coords/time
          .select(
              F.col("p.issue_time").alias("issue_time"),
              F.col("p.valid_time").alias("valid_time"),
              F.col("p.lat").alias("lat"),
              F.col("p.lon").alias("lon"),
              F.col("u.y_obs_c").alias("y_obs_c")
          ))

    j = (j1.join(pr, ["valid_time","lat","lon"], "left_anti"))

    if j.limit(1).count() == 0:
        return "no_new_pairs"

    # build feature bank for this block/run_time
    W, _ = build_block_wide(rt_ts, block_id)
    Wpdf = W.toPandas()
    if Wpdf.empty:
        return "no_wide"

    Wpdf["block_flag"] = Wpdf["block_id"].astype(np.float32)
    Xall = Wpdf[FEATURES].to_numpy(np.float32)
    Gall = Wpdf[["g0","g1","g2"]].to_numpy(np.float32)
    Xz_all = scaler.z(Xall)  # current scaler snapshot for eval canary
    # index by exact lat/lon (same precision as in tables)
    idx = {(float(Wpdf.loc[i, "lat"]), float(Wpdf.loc[i, "lon"])): i for i in range(len(Wpdf))}

    # supervised set (residuals per correct lead)
    ppdf = (j.withColumn(
                "lead",
                ((F.unix_timestamp("valid_time") - F.unix_timestamp("issue_time"))/3600).cast("int")
            )
            .select("valid_time","lat","lon","lead","y_obs_c")
            .toPandas())

    Xsup, Rsup, eval_triplets = [], [], []
    for _, row in ppdf.iterrows():
        k = int(row["lead"]) - base_lead
        if k not in (0, 1, 2):
            continue
        key = (float(row["lat"]), float(row["lon"]))
        i = idx.get(key)
        if i is None:
            continue
        r = [0.0, 0.0, 0.0]
        Gk = float(Gall[i, k])
        Yk = float(row["y_obs_c"])
        r[k] = Yk - Gk
        Xsup.append(Xall[i]); Rsup.append(r)
        eval_triplets.append((i, k, Gk, Yk))

    if len(Xsup) < MIN_SUP_PAIRS:
        return f"too_few_pairs({len(Xsup)})"

    # update scaler on raw features then train with standardized batch
    scaler.update(np.stack(Xsup, axis=0))
    save_scaler(scaler)

    Xz = scaler.z(np.stack(Xsup, axis=0))
    R  = np.stack(Rsup, axis=0).astype(np.float32)

    # lightweight update with rollback canary
    model.train()
    pre_state = {k: v.clone() for k, v in model.state_dict().items()}
    opt = torch.optim.Adam(model.parameters(), lr=LR_UPDATE, weight_decay=WEIGHT_DECAY)
    loss_fn = nn.SmoothL1Loss()

    for _ in range(EPOCHS_UPDATE):
        for st in range(0, len(Xz), BATCH_UPDATE):
            ed = min(st + BATCH_UPDATE, len(Xz))
            xb = torch.from_numpy(Xz[st:ed])
            rb = torch.from_numpy(R[st:ed])
            opt.zero_grad()
            out = model(xb)
            loss = loss_fn(out, rb)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), CLIP_NORM)
            opt.step()
    model.eval()

    # canary (compare to GFS)
    with torch.no_grad():
        rhat_all = model(torch.from_numpy(Xz_all)).cpu().numpy().astype(np.float32)

    y_gfs, y_hat, y_obs = [], [], []
    for (i, k, Gk, Yk) in eval_triplets:
        y_gfs.append(Gk)
        y_obs.append(Yk)
        y_hat.append(float(Gall[i, k] + rhat_all[i, k]))

    mae_gfs = mae_np(y_gfs, y_obs)
    mae_mdl = mae_np(y_hat,  y_obs)

    if mae_mdl > mae_gfs + WORSE_TOLERANCE_C:
        model.load_state_dict(pre_state)
        msg = f"rollback (model {mae_mdl:.3f} > gfs {mae_gfs:.3f}+{WORSE_TOLERANCE_C:.2f})"
    else:
        save_model(model)
        msg = f"updated {len(Xsup)} pairs; MAE mdl={mae_mdl:.3f} vs gfs={mae_gfs:.3f}"

    # idempotency log (tz aware to satisfy Spark and Arrow path)
    now_aw = to_aware_utc(pd.Timestamp.utcnow())
    it_aw  = to_aware_utc(as_naive_utc(rt_ts))

    pj = j.select("valid_time","lat","lon").distinct().toPandas()
    if not pj.empty:
        rows = [
            (it_aw, to_aware_utc(r["valid_time"]), float(r["lat"]), float(r["lon"]), now_aw)
            for _, r in pj.iterrows()
        ]
        sdf = spark.createDataFrame(
            rows,
            "issue_time TIMESTAMP, valid_time TIMESTAMP, lat DOUBLE, lon DOUBLE, processed_ts TIMESTAMP"
        )
        sdf.write.mode("append").saveAsTable(f"{GOLD}.online_training_log")

    # metrics
    day_iso = as_naive_utc(rt).date().isoformat()
    metrics = [
        (day_iso, f"gfs_mae_canary_b{block_id}", float(mae_gfs)),
        (day_iso, f"mdl_mae_canary_b{block_id}", float(mae_mdl)),
        (day_iso, f"pairs_b{block_id}",           float(len(Xsup))),
    ]
    (spark.createDataFrame(metrics, "d STRING, metric STRING, value DOUBLE")
         .select(F.to_date("d").alias("day"), "metric", "value")
         .write.mode("append").saveAsTable(f"{GOLD}.daily_metrics"))

    return msg

# %%
def run_cycle(rt_ts):
    # 1) Ingest data for this cycle (GFS + URMA for +3..8 valid times)
    print('Ingestion Started...\n')
    ingest_cycle(rt_ts)
    print('Ingestion Complete \n')

    # 2) Regrid URMA hours for this cycle to target grid (+3..8)
    print(f"Regridding URMA... \n")
    rt = as_naive_utc(rt_ts)
    for h in range(3, MAX_LEAD+1):
        regrid_urma_to_gfs(rt + pd.Timedelta(hours=h))
    print(f"Regridding URMA...done\n")

    # 3) Build silver features for just this cycle
    print(f"Building silver features...\n")
    build_silver_features_for_cycle(rt_ts)
    print(f"Building silver features...done\n")

    # 4) Load state
    print(f"Loading model...\n")
    model  = load_or_init_model()
    print(f"Loading model...done\n")

    print(f"Loading scaler...\n")
    scaler = load_or_init_scaler()
    print(f"Loading scaler...done\n")


    # 5) BLOCK 0: predict to update
    print(f"Predicting block 0...\n")
    n0 = predict_block(rt_ts, block_id=0, model=model, scaler=scaler)
    msg0 = update_block(rt_ts, block_id=0, model=model, scaler=scaler)
    print(f"Predicting block 0...done\n")

    # 6) BLOCK 1: predict to update
    print(f"Predicting block 1...\n")
    n1 = predict_block(rt_ts, block_id=1, model=model, scaler=scaler)
    msg1 = update_block(rt_ts, block_id=1, model=model, scaler=scaler)
    print(f"Predicting block 1...done\n")

    print(f"[{rt_ts}] b0 wrote={n0}, update={msg0} | b1 wrote={n1}, update={msg1}")

def run_day(day_str):
    # create 00:00 UTC as tz naive
    base = as_naive_utc(day_str + " 00:00:00")
    for hr in (0,6,12,18):
        rt = base + pd.Timedelta(hours=hr)
        run_cycle(rt.strftime("%Y-%m-%d %H:%M:%S"))

def run_range(start_ts, end_ts):
    runs = cycle_hours(as_naive_utc(start_ts), as_naive_utc(end_ts))
    for rt in runs:
        run_cycle(rt.strftime("%Y-%m-%d %H:%M:%S"))

print("Online block-aware pipeline ready.")
# Out:
# Online block-aware pipeline ready.

# %%
# One day:
run_day("2024-10-01")

# Full window:
# run_range(ONLINE_START, ONLINE_END)
# Out:
# Ingestion Started...
#
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 00:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 00:00 UTC F01 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 00:00 UTC F02 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 00:00 UTC F04 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 00:00 UTC F05 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 00:00 UTC F07 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 00:00 UTC F08 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 03:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# 👨🏻‍🏭 Created directory: [/tmp/herbie_cache/urma/urma/20241001]
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 04:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 05:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 06:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 07:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 08:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# Ingestion Complete
#
# Regridding URMA...
#
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 03:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 04:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 05:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 06:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 07:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 08:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# Regridding URMA...done
#
# Building silver features...
#
# Building silver features...done
#
# Loading model...
#
# Loading model...done
#
# Loading scaler...
#
# Loading scaler...done
#
# Predicting block 0...
#
# Predicting block 0...done
#
# Predicting block 1...
#
# Predicting block 1...done
#
# [2024-10-01 00:00:00] b0 wrote=118863, update=updated 106716 pairs; MAE mdl=1.273 vs gfs=1.236 | b1 wrote=118863, update=updated 106716 pairs; MAE mdl=1.353 vs gfs=1.368
# Ingestion Started...
#
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 06:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 06:00 UTC F01 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 06:00 UTC F02 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 06:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 06:00 UTC F04 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 06:00 UTC F05 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 06:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 06:00 UTC F07 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 06:00 UTC F08 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 09:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 10:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 11:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 12:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 13:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 14:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# Ingestion Complete
#
# Regridding URMA...
#
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 09:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 10:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 11:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 12:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 13:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 14:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# Regridding URMA...done
#
# Building silver features...
#
# Building silver features...done
#
# Loading model...
#
# Loading model...done
#
# Loading scaler...
#
# Loading scaler...done
#
# Predicting block 0...
#
# Predicting block 0...done
#
# Predicting block 1...
#
# Predicting block 1...done
#
# [2024-10-01 06:00:00] b0 wrote=118863, update=updated 106716 pairs; MAE mdl=1.387 vs gfs=1.432 | b1 wrote=118863, update=updated 106716 pairs; MAE mdl=1.402 vs gfs=1.472
# Ingestion Started...
#
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 12:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 12:00 UTC F01 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 12:00 UTC F02 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 12:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 12:00 UTC F04 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 12:00 UTC F05 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 12:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 12:00 UTC F07 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 12:00 UTC F08 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 15:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 16:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 17:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 18:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 19:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 20:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# Ingestion Complete
#
# Regridding URMA...
#
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 15:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 16:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 17:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 18:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 19:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 20:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# Regridding URMA...done
#
# Building silver features...
#
# Building silver features...done
#
# Loading model...
#
# Loading model...done
#
# Loading scaler...
#
# Loading scaler...done
#
# Predicting block 0...
#
# Predicting block 0...done
#
# Predicting block 1...
#
# Predicting block 1...done
#
# [2024-10-01 12:00:00] b0 wrote=118863, update=updated 106716 pairs; MAE mdl=1.108 vs gfs=1.183 | b1 wrote=118863, update=updated 106716 pairs; MAE mdl=1.049 vs gfs=1.099
# Ingestion Started...
#
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 18:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 18:00 UTC F01 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 18:00 UTC F02 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 18:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 18:00 UTC F04 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 18:00 UTC F05 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 18:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 18:00 UTC F07 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gfs ┊ product=pgrb2.0p25 ┊ 2024-Oct-01 18:00 UTC F08 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 21:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 22:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 23:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-02 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# 👨🏻‍🏭 Created directory: [/tmp/herbie_cache/urma/urma/20241002]
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-02 01:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-02 02:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# Ingestion Complete
#
# Regridding URMA...
#
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 21:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 22:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-01 23:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-02 00:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-02 01:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# ✅ Found ┊ model=urma ┊ product=anl ┊ 2024-Oct-02 02:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# Regridding URMA...done
#
# Building silver features...
#
# Building silver features...done
#
# Loading model...
#
# Loading model...done
#
# Loading scaler...
#
# Loading scaler...done
#
# Predicting block 0...
#
# Predicting block 0...done
#
# Predicting block 1...
#
# Predicting block 1...done
#
# [2024-10-01 18:00:00] b0 wrote=118863, update=updated 106716 pairs; MAE mdl=1.017 vs gfs=1.055 | b1 wrote=118863, update=updated 106716 pairs; MAE mdl=1.101 vs gfs=1.128

# %% [markdown]
# # Data Processing Confirmation

# %%
# %sql
-- Create a daily progress view across all cycles
CREATE OR REPLACE VIEW weather_ml.gold.daily_cycle_progress AS
WITH plc AS (
  SELECT
    issue_time,
    CAST(ROUND((unix_timestamp(valid_time) - unix_timestamp(issue_time)) / 3600.0) AS INT) AS lead,
    COUNT(*) AS n_rows
  FROM weather_ml.gold.predictions_grid_online
  GROUP BY issue_time,
           CAST(ROUND((unix_timestamp(valid_time) - unix_timestamp(issue_time)) / 3600.0) AS INT)
),
per_cycle AS (
  SELECT
    issue_time,
    /* block completeness from leads */
    CASE WHEN SUM(CASE WHEN lead IN (3,4,5) THEN 1 ELSE 0 END) = 3 THEN 1 ELSE 0 END AS b0_done,
    CASE WHEN SUM(CASE WHEN lead IN (6,7,8) THEN 1 ELSE 0 END) = 3 THEN 1 ELSE 0 END AS b1_done,
    MAX(n_rows) AS grid_rows_per_lead
  FROM plc
  GROUP BY issue_time
),
cycles AS (
  SELECT
    issue_time,
    HOUR(issue_time) AS zhr,
    CASE WHEN b0_done = 1 AND b1_done = 1 THEN 1 ELSE 0 END AS cycle_complete
  FROM per_cycle
),
per_day AS (
  SELECT
    DATE(issue_time) AS day,
    MAX(CASE WHEN zhr = 0  THEN cycle_complete END) AS z00_done,
    MAX(CASE WHEN zhr = 6  THEN cycle_complete END) AS z06_done,
    MAX(CASE WHEN zhr = 12 THEN cycle_complete END) AS z12_done,
    MAX(CASE WHEN zhr = 18 THEN cycle_complete END) AS z18_done,
    COUNT(*)                                 AS cycles_seen,
    SUM(CASE WHEN cycle_complete = 1 THEN 1 ELSE 0 END) AS cycles_completed,
    SUM(CASE WHEN cycle_complete = 1 THEN 2 ELSE 0 END) AS blocks_completed
  FROM cycles
  GROUP BY DATE(issue_time)
)
SELECT
  day,
  COALESCE(z00_done, 0) AS z00_done,
  COALESCE(z06_done, 0) AS z06_done,
  COALESCE(z12_done, 0) AS z12_done,
  COALESCE(z18_done, 0) AS z18_done,
  cycles_seen,
  cycles_completed,
  blocks_completed,
  /* percent of planned cycles (4/day) completed */
  ROUND(100.0 * COALESCE(cycles_completed,0) / 4.0, 1) AS pct_day_complete
FROM per_day
ORDER BY day;

# %%
# %sql
-- See all days’ progress
SELECT * FROM weather_ml.gold.daily_cycle_progress ORDER BY day;

-- Today’s (or a specific day’s) snapshot
SELECT * FROM weather_ml.gold.daily_cycle_progress WHERE day = DATE '2024-10-01';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>day</th><th>z00_done</th><th>z06_done</th><th>z12_done</th><th>z18_done</th><th>cycles_seen</th><th>cycles_completed</th><th>blocks_completed</th><th>pct_day_complete</th></tr></thead><tbody><tr><td>2024-10-01</td><td>1</td><td>1</td><td>1</td><td>1</td><td>4</td><td>4</td><td>8</td><td>100.0</td></tr></tbody></table></div>

# %% [markdown]
# # Post Prediction Analysis

# %%
 # %sql
-- Are canary metrics improving?
SELECT day,
       MAX(CASE WHEN metric LIKE 'gfs_mae_canary_b0' THEN value END) AS gfs_b0,
       MAX(CASE WHEN metric LIKE 'mdl_mae_canary_b0' THEN value END) AS mdl_b0,
       MAX(CASE WHEN metric LIKE 'gfs_mae_canary_b1' THEN value END) AS gfs_b1,
       MAX(CASE WHEN metric LIKE 'mdl_mae_canary_b1' THEN value END) AS mdl_b1
FROM weather_ml.gold.daily_metrics
GROUP BY day
ORDER BY day DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>day</th><th>gfs_b0</th><th>mdl_b0</th><th>gfs_b1</th><th>mdl_b1</th></tr></thead><tbody><tr><td>2024-10-01</td><td>1.4324996558179062</td><td>1.3868327372603015</td><td>1.4719473417250577</td><td>1.4016291686195863</td></tr></tbody></table></div>

# %%
# ===== Visualizations: Model vs GFS =====
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

CAT = "weather_ml"
BRONZE = f"{CAT}.bronze"
SILVER = f"{CAT}.silver"
GOLD   = f"{CAT}.gold"

# Pick day = latest present in predictions
day_pdf = spark.sql(f"SELECT MAX(DATE(issue_time)) AS day FROM {GOLD}.predictions_grid_online").toPandas()
DAY = str(day_pdf['day'].iloc[0])

# Build evaluation join (Preds + URMA + GFS), rounded lat/lon
spark.sql(f"""
CREATE OR REPLACE TEMP VIEW v_eval AS
WITH p AS (
  SELECT issue_time, valid_time,
         ROUND(CAST(lat AS DOUBLE), 6) AS lat6,
         ROUND(CAST(lon AS DOUBLE), 6) AS lon6,
         CAST(y_hat_c AS DOUBLE) AS y_hat_c
  FROM {GOLD}.predictions_grid_online
  WHERE DATE(issue_time) = DATE('{DAY}')
),
u AS (
  SELECT valid_time,
         ROUND(CAST(lat AS DOUBLE), 6) AS lat6,
         ROUND(CAST(lon AS DOUBLE), 6) AS lon6,
         CAST(y_obs_c AS DOUBLE) AS y_obs_c
  FROM {SILVER}.silver_urma_on_gfs
),
pu AS (
  SELECT
    p.issue_time,
    p.valid_time,
    p.lat6, p.lon6,
    p.y_hat_c,
    u.y_obs_c,
    CAST(ROUND((unix_timestamp(p.valid_time) - unix_timestamp(p.issue_time)) / 3600.0) AS INT) AS lead
  FROM p JOIN u
    ON p.valid_time = u.valid_time
   AND p.lat6 = u.lat6 AND p.lon6 = u.lon6
),
g AS (
  SELECT run_time AS issue_time,
         CAST(lead_hour AS INT) AS lead,
         ROUND(CAST(lat AS DOUBLE), 6) AS lat6,
         ROUND(CAST(lon AS DOUBLE), 6) AS lon6,
         CAST(value_c AS DOUBLE) AS gfs_t2m_c
  FROM {BRONZE}.bronze_gfs_grid
  WHERE var = 't2m'
)
SELECT
  pu.issue_time, pu.valid_time, pu.lead, pu.lat6, pu.lon6,
  pu.y_obs_c, pu.y_hat_c, g.gfs_t2m_c
FROM pu
JOIN g
  ON g.issue_time = pu.issue_time
 AND g.lead = pu.lead
 AND g.lat6 = pu.lat6 AND g.lon6 = pu.lon6
WHERE pu.lead BETWEEN 3 AND 8
""")

to_pd = lambda q: spark.sql(q).toPandas()

# %%
# Overall KPI
overall = to_pd("""
SELECT
  AVG(ABS(y_obs_c - gfs_t2m_c)) AS mae_gfs,
  AVG(ABS(y_obs_c - y_hat_c)) AS mae_model,
  COUNT(*) AS n
FROM v_eval
""")
mg = float(overall.mae_gfs.iloc[0]); mm = float(overall.mae_model.iloc[0]); N = int(overall.n.iloc[0])
impr_pct = (mg - mm) / mg * 100.0

subtitle = f"Day = {DAY} • CONUS 0.25° • n = {N:,}"

plt.figure(figsize=(3,2))
plt.axis('off')
txt = (f"Overall MAE\n"
       f"GFS: {mg:.2f} °C   •   Model: {mm:.2f} °C\n"
       f"Improvement vs GFS: {impr_pct:.1f}%")
plt.text(0.02, 0.60, "Scoreboard", fontsize=16, weight='bold')
plt.text(0.02, 0.20, txt, fontsize=13)
plt.text(0.02, -0.05, subtitle, fontsize=10, alpha=0.75)
plt.tight_layout()
plt.show()

# %%
# MAE by cycle (00/06/12/18Z) with delta vs GFS annotations and tight y-axis
mae_cycle = to_pd("""
SELECT HOUR(issue_time) AS zhr,
       AVG(ABS(y_obs_c - gfs_t2m_c))  AS mae_gfs,
       AVG(ABS(y_obs_c - y_hat_c))    AS mae_model,
       COUNT(*) AS n
FROM v_eval
GROUP BY HOUR(issue_time)
ORDER BY zhr
""")
mae_cycle["zlabel"] = mae_cycle["zhr"].map({0:"00Z",6:"06Z",12:"12Z",18:"18Z"})

# Ensure numeric dtype (avoid Decimal issues)
mae_cycle["mae_gfs"] = mae_cycle["mae_gfs"].astype(float)
mae_cycle["mae_model"] = mae_cycle["mae_model"].astype(float)

# Compute per-cycle deltas (Model - GFS)
mae_cycle["delta"] = mae_cycle["mae_model"] - mae_cycle["mae_gfs"]

fig, ax = plt.subplots(figsize=(7, 4.5))
idx = np.arange(len(mae_cycle))
w = 0.35

ax.bar(idx - w/2, mae_cycle["mae_gfs"].values, width=w, label="GFS MAE")
ax.bar(idx + w/2, mae_cycle["mae_model"].values, width=w, label="Model MAE")

# Tight y-axis
ymin = float(min(mae_cycle["mae_gfs"].min(), mae_cycle["mae_model"].min()))
ymax = float(max(mae_cycle["mae_gfs"].max(), mae_cycle["mae_model"].max()))
pad = max(0.03, 0.12 * (ymax - ymin) if ymax > ymin else 0.05)
lo, hi = max(0.0, ymin - pad), ymax + pad

if lo >= 1.0 and hi <= 1.5:
    ax.set_ylim(1.0, 1.5)
else:
    ax.set_ylim(lo, hi)

# Δ vs GFS labels above the model bars
for i in range(len(mae_cycle)):
    y_model = mae_cycle["mae_model"].iloc[i]
    d = mae_cycle["delta"].iloc[i]
    ax.text(
        idx[i] + w/2, y_model + pad * 0.90,
        f"Δ {d:+.2f} °C",
        ha="center", va="bottom", fontsize=9
    )

ax.set_xticks(idx)
ax.set_xticklabels(mae_cycle["zlabel"].tolist())
ax.set_xlabel("Cycle")
ax.set_ylabel("MAE (°C)")
ax.set_title(f"MAE by Cycle")
ax.legend(loc="best")
ax.grid(axis="y", linestyle="--", alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Win rate by lead: fraction of gridpoints where |model error| < |GFS error|
win_lead = to_pd("""
SELECT lead,
       AVG(CASE WHEN ABS(y_obs_c - y_hat_c) < ABS(y_obs_c - gfs_t2m_c) THEN 1.0 ELSE 0.0 END) AS win_rate,
       COUNT(*) AS n
FROM v_eval
GROUP BY lead
ORDER BY lead
""")
win_lead["win_rate"] = pd.to_numeric(win_lead["win_rate"])
win_lead["pct"] = 100.0 * win_lead["win_rate"]

subtitle = f"Day = {DAY} • CONUS 0.25° • n = {N:,}"

plt.figure(figsize=(7,4.5))
x = win_lead["lead"].astype(int).values
y = win_lead["pct"].values
bars = plt.bar(x, y)
for i, v in enumerate(y):
    plt.text(x[i], v, f"{v:.1f}%", ha="center", va="bottom", fontsize=9)
plt.axhline(50, linestyle="--", linewidth=1)  # 50% = parity with GFS
plt.xlabel("Lead hour (relative to issue time)")
plt.ylabel("Win-rate vs GFS (%)")
plt.title(f"How Often the Model Beats GFS (by Lead)")
plt.tight_layout()
plt.show()

# %%
# ============================
# Win-Rate Map (Model vs GFS)
# ============================
# Blue = model wins more often
# Red = GFS wins more often
# Win = |Model error| < |GFS error|

import numpy as np, pandas as pd, matplotlib.pyplot as plt
from matplotlib.colors import TwoSlopeNorm
import cartopy.crs as ccrs, cartopy.feature as cfeature

CAT="weather_ml"; BRONZE=f"{CAT}.bronze"; SILVER=f"{CAT}.silver"; GOLD=f"{CAT}.gold"

# Pick the day to summarize (auto = latest in predictions)
DAY = spark.sql(f"SELECT MAX(DATE(issue_time)) AS d FROM {GOLD}.predictions_grid_online").toPandas()['d'].iloc[0]
DAY = str(DAY)  # e.g., '2024-10-01'

# Minimum samples per cell to show (mask sparse cells)
MIN_N = 8  # up to 24/cell (4 cycles × 6 leads)

# Build per-point comparisons for the day
q = f"""
WITH p AS (
  SELECT issue_time, valid_time,
         ROUND(CAST(lat AS DOUBLE),6) AS lat6,
         ROUND(CAST(lon AS DOUBLE),6) AS lon6,
         CAST(y_hat_c AS DOUBLE) AS y_hat_c
  FROM {GOLD}.predictions_grid_online
  WHERE DATE(issue_time) = DATE('{DAY}')
),
u AS (
  SELECT valid_time,
         ROUND(CAST(lat AS DOUBLE),6) AS lat6,
         ROUND(CAST(lon AS DOUBLE),6) AS lon6,
         CAST(y_obs_c AS DOUBLE) AS y_obs_c
  FROM {SILVER}.silver_urma_on_gfs
),
g AS (
  SELECT run_time AS issue_time,
         CAST(lead_hour AS INT) AS lead,
         ROUND(CAST(lat AS DOUBLE),6) AS lat6,
         ROUND(CAST(lon AS DOUBLE),6) AS lon6,
         CAST(value_c AS DOUBLE) AS gfs_t2m_c
  FROM {BRONZE}.bronze_gfs_grid
  WHERE var='t2m'
),
pu AS (
  SELECT
    p.issue_time, p.valid_time, p.lat6, p.lon6, p.y_hat_c, u.y_obs_c,
    CAST(ROUND((unix_timestamp(p.valid_time) - unix_timestamp(p.issue_time)) / 3600.0) AS INT) AS lead
  FROM p JOIN u
    ON p.valid_time = u.valid_time AND p.lat6 = u.lat6 AND p.lon6 = u.lon6
)
SELECT
  pu.lat6, pu.lon6,
  ABS(pu.y_obs_c - pu.y_hat_c)     AS ae_model,
  ABS(pu.y_obs_c - g.gfs_t2m_c)    AS ae_gfs
FROM pu
JOIN g
  ON g.issue_time = pu.issue_time AND g.lead = pu.lead
 AND g.lat6 = pu.lat6 AND g.lon6 = pu.lon6
WHERE pu.lead BETWEEN 3 AND 8
"""
df = spark.sql(q).toPandas()
for c in ["lat6","lon6","ae_model","ae_gfs"]:
    df[c] = pd.to_numeric(df[c], errors="coerce")

# Win flag per point, then aggregate per cell
df["win"] = (df["ae_model"] < df["ae_gfs"]).astype("float32")
agg = (df.groupby(["lat6","lon6"])
         .agg(win_rate=("win","mean"), n=("win","size"))
         .reset_index())
agg["win_pct"] = 100.0 * agg["win_rate"].astype(float)

# Pivot to 2-D grids
lats = np.sort(agg["lat6"].unique())
lons = np.sort(agg["lon6"].unique())
Z_win = (agg.pivot(index="lat6", columns="lon6", values="win_pct")
             .reindex(index=lats, columns=lons).values)
Z_n   = (agg.pivot(index="lat6", columns="lon6", values="n")
             .reindex(index=lats, columns=lons).values)

# Mask sparse cells
Z_plot = Z_win.copy().astype(float)
Z_plot[Z_n < MIN_N] = np.nan

# Map extent + normalization centered at 50%
extent = [float(lons.min()), float(lons.max()), float(lats.min()), float(lats.max())]
norm = TwoSlopeNorm(vmin=0, vcenter=50, vmax=100)

# Summary strings
medN = int(np.nanmedian(Z_n))
title = f"Win-Rate Map (Model vs GFS) • {DAY}"
subtitle = f"Blue = Model wins more often • Win = |Model−URMA| < |GFS−URMA|"

# Plot
fig = plt.figure(figsize=(10,6))
ax  = fig.add_subplot(1,1,1, projection=ccrs.PlateCarree())
ax.set_extent(extent, crs=ccrs.PlateCarree())

im = ax.pcolormesh(lons, lats, Z_plot, cmap="RdBu", norm=norm, shading="auto", transform=ccrs.PlateCarree())
ax.coastlines(resolution="50m", linewidth=0.6)
try: ax.add_feature(cfeature.STATES.with_scale("50m"), linewidth=0.25, edgecolor="k")
except Exception: pass

cb = plt.colorbar(im, ax=ax, pad=0.02)
cb.set_label("Win-rate vs GFS (%)")

ax.set_title(title, fontsize=13, pad=6)
ax.text(0.5, -0.10, subtitle, ha="center", va="top", transform=ax.transAxes, fontsize=9)
plt.tight_layout()
plt.show()
